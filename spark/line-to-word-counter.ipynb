# %%
import csv

# %%
#Все что str - то слово :) 

with open('movies.csv', 'r') as mv:
    _dict = {}
    spamreader = csv.reader(mv, delimiter=',', quotechar='\n')
    for line in spamreader:
        
        init_line = line[1].lower().replace('"','')\
                                   .replace('.','')\
                                   .replace(':','')\
                                   .replace('(','')\
                                   .replace(')','')\
                                   .replace('-','')\
                                   .replace("'",'')\
                                   .replace("'s",'')\
                                   .split()
        for word in init_line:
            if word in _dict.keys():
                _dict[word] += 1
            else:
                _dict[word] = 1
                
    for w in sorted(_dict, key=_dict.get, reverse=True):
        print(w, _dict[w])
# Out:
# the 1324
# of 949
# and 339
# in 298
# a 245
# 2000 222
# 2002 221
# 1996 220
# 2001 215
# 1997 213
# to 211
# 1998 209
# 2007 209
# 1995 206
# 1999 198
# 2004 198
# 2006 198
# 2008 196
# 2009 195
# 2014 192
# 1994 184
# 2005 184
# 2010 182
# 2003 180
# 2011 177
# 2015 176
# 2013 174
# 2012 172
# 1993 158
# 2 139
# man 138
# 1988 129
# 1987 122
# 1992 120
# on 118
# 1991 118
# 1989 118
# 1990 116
# 1986 109
# & 105
# 1985 103
# for 95
# ii 94
# my 94
# aka 92
# love 90
# i 88
# with 85
# night 80
# life 76
# 1982 74
# from 72
# 1984 72
# story 71
# movie 71
# 1981 71
# 1983 70
# no 68
# is 66
# me 66
# 1980 66
# last 65
# dead 64
# 2016 63
# you 61
# day 60
# american 59
# at 59
# 3 58
# big 57
# little 54
# it 52
# house 52
# one 52
# world 51
# girl 49
# men 47
# black 47
# 1978 47
# time 46
# de 45
# new 45
# 1979 45
# death 44
# 1977 43
# iii 41
# king 41
# 1971 41
# mr 40
# up 40
# white 39
# 1967 39
# blue 39
# days 39
# red 39
# all 39
# city 38
# war 37
# star 36
# 1973 36
# ...
